# %%
sdne_email_hyp = {16 : {'sdne' : {'lr' : 1e-3, 
                     'alpha' : 0.1, 
                     'beta' : 10, 
                     'gamma' : 0, 
                     'delta' : 0, 
                     'epochs' : 100}, 
             
             'sdne+ init' : {'lr' : 1e-4, 
                         'alpha' : 10, 
                         'beta' : 1, 
                         'gamma' : 10,
                         'delta' : 10, 
                         'epochs' : 400}, 
             
            
            },  
      
      32 : {'sdne' : {'lr' : 1e-3, 
                     'alpha' : 0.1, 
                     'beta' : 10, 
                     'gamma' : 0, 
                     'delta' : 0, 
                     'epochs' : 100}, 
             
             'sdne+ init' : {'lr' : 9e-4, 
                         'alpha' : 10, 
                         'beta' : 1, 
                         'gamma' : 100, 
                         'delta' : 100, 
                         'epochs' : 400}, 
             
           
            },
      64 : {'sdne' : {'lr' : 1e-3, 
                     'alpha' : 0.1, 
                     'beta' : 10, 
                     'gamma' : 0, 
                     'delta' : 0, 
                     'epochs' : 200}, 
             
             'sdne+ init' : {'lr' : 1e-4, 
                         'alpha' : 10, 
                         'beta' : 1, 
                         'gamma' : 100,
                         'delta' : 100, 
                         'epochs' : 400}, 
            
            }, 
    
      128 : {'sdne' : {'lr' : 1e-3, 
                     'alpha' : 0.1, 
                     'beta' : 10, 
                     'gamma' : 0, 
                     'delta' : 0, 
                     'epochs' : 200}, 
             
             'sdne+ init' : {'lr' : 5e-4, 
                         'alpha' : 1, 
                         'beta' : 1, 
                         'gamma' : 10,
                         'delta' : 10, 
                         'epochs' : 400}, 
             
           
            }, 
      
      256 : {'sdne' : {'lr' : 1e-3, 
                     'alpha' : 0.1, 
                     'beta' : 10, 
                     'gamma' : 0, 
                     'delta' : 0, 
                     'epochs' : 200}, 
             
             'sdne+ init' : {'lr' : 5e-4, 
                         'alpha' : 10, 
                         'beta' : 1, 
                         'gamma' : 100,
                         'delta' : 100, 
                         'epochs' : 400}, 
             
           
            }}

# %%
sdne_airport_hyp = {
        16 : {'sdne' : {'lr' : 1e-3, 
                     'alpha' : 0.1, 
                     'beta' : 10, 
                     'gamma' : 0, 
                     'delta' : 0, 
                     'epochs' : 100}, 
             
             'sdne+ init' : {'lr' : 5e-4, 
                         'alpha' : 1, 
                         'beta' : 1, 
                         'gamma' : 100,
                         'delta' : 100, 
                         'epochs' : 400}, 
            },
           
      
      32 : {'sdne' : {'lr' : 1e-3, 
                     'alpha' : 0.1, 
                     'beta' : 10, 
                     'gamma' : 0, 
                     'delta' : 0, 
                     'epochs' : 100}, 
             
             'sdne+ init' : {'lr' : 1e-4, 
                         'alpha' : 1, 
                         'beta' : 10, 
                         'gamma' : 10,
                         'delta' : 1000, 
                         'epochs' : 800}, 
            },
             
         
      64 : {'sdne' : {'lr' : 1e-3, 
                     'alpha' : 0.1, 
                     'beta' : 10, 
                     'gamma' : 0, 
                     'delta' : 0, 
                     'epochs' : 100}, 
             
             'sdne+ init' : {'lr' : 5e-4, 
                         'alpha' : 1, 
                         'beta' : 10, 
                         'gamma' : 1000,
                         'delta' : 1000, 
                         'epochs' : 400}, 
            }, 
            
    
      128 : {'sdne' : {'lr' : 1e-3, 
                     'alpha' : 0.1, 
                     'beta' : 10, 
                     'gamma' : 0, 
                     'delta' : 0, 
                     'epochs' : 100}, 
             
             'sdne+ init' : {'lr' : 5e-4, 
                         'alpha' : 1, 
                         'beta' : 10, 
                         'gamma' : 1000,
                         'delta' : 1000, 
                         'epochs' : 400}, 
            }, 
      
      256 : {'sdne' : {'lr' : 1e-3, 
                     'alpha' : 0.1, 
                     'beta' : 10, 
                     'gamma' : 0, 
                     'delta' : 0, 
                     'epochs' : 100}, 
             
            'sdne+ init' : {'lr' : 1e-4, 
                         'alpha' : 1, 
                         'beta' : 10, 
                         'gamma' : 1,
                         'delta' : 100, 
                         'epochs' : 800}, 
            },
}

# %%
line_general_hyp = {
    
    16 : {'line' : {'lr' : 1e-3, 
                     'alpha' : 1, 
                     'ortho' : 0, 
                     'sparse' : 0, 
                     'epochs' : 15}, 
             
             'line+ init' : {'lr' : 9e-4, 
                         'alpha' : 100, 
                         'ortho' : 1, 
                         'sparse' : 1, 
                         'epochs' : 50}, 

            },
       
        32 : {'line' : {'lr' : 1e-3, 
                     'alpha' : 1, 
                     'ortho' : 0, 
                     'sparse' : 0, 
                     'epochs' : 15}, 
             
             'line+ init' : {'lr' : 9e-4, 
                         'alpha' : 100, 
                         'ortho' : 10, 
                         'sparse' : 10, 
                         'epochs' : 50}, 

            },
       
       64 : {'line' : {'lr' : 1e-3, 
                     'alpha' : 1, 
                     'ortho' : 0, 
                     'sparse' : 0, 
                     'epochs' : 15}, 
             
             'line+ init' : {'lr' : 9e-4, 
                         'alpha' : 100, 
                         'ortho' : 10, 
                         'sparse' : 10, 
                         'epochs' : 50}, 

            },
       
        128 : {'line' : {'lr' : 1e-3, 
                     'alpha' : 1, 
                     'ortho' : 0, 
                     'sparse' : 0, 
                     'epochs' : 15}, 
             
             'line+ init' : {'lr' : 9e-4, 
                         'alpha' : 100, 
                         'ortho' : 10, 
                         'sparse' : 10, 
                         'epochs' : 50}, 

            },
       
       256 : {'line' : {'lr' : 1e-3, 
                     'alpha' : 1, 
                     'ortho' : 0, 
                     'sparse' : 0, 
                     'epochs' : 15}, 
             
             'line+ init' : {'lr' : 9e-4, 
                         'alpha' : 100, 
                         'ortho' : 10, 
                         'sparse' : 10, 
                         'epochs' : 50}, 

            },
      
     }
